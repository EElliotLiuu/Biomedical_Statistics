# %%
#加载头文件
import numpy as np
import pandas as pd
import scipy.stats as stats
import statistics as sta
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
#中文显示设置
plt.rcParams["font.family"] = ["SimHei", "Microsoft YaHei"]

# %%
x=np.random.normal(0,1,100)
y=np.random.normal(1,1,100)
z=np.random.normal(2,1,100)

plt.figure(figsize=(8, 5))
sns.kdeplot(x,color="lightblue")
sns.kdeplot(y,color="pink")
sns.kdeplot(z,color="grey")
plt.show()

# %%
x=np.random.normal(0,0.1,100)
y=np.random.normal(1,0.1,100)
z=np.random.normal(2,0.1,100)

plt.figure(figsize=(8, 5))
sns.kdeplot(x,color="lightblue")
sns.kdeplot(y,color="pink")
sns.kdeplot(z,color="grey")
plt.show()

# %%
x=np.random.normal(0,1,100)
y=np.random.normal(4,1,100)
z=np.random.normal(8,1,100)

plt.figure(figsize=(8, 5))
sns.kdeplot(x,color="lightblue")
sns.kdeplot(y,color="pink")
sns.kdeplot(z,color="grey")
plt.show()
